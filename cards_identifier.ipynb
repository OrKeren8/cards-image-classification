# %% [markdown]
# # Initialize Repository for Jupyter Notebook Usage
#
# This notebook guides you through initializing a repository for Jupyter notebook usage.

# %% [markdown]
# ## 1. Initialize Git Repository
#
# Use git commands to initialize a new Git repository in the project directory.

# %%
# !git init

# %% [markdown]
# ## 2. Create Virtual Environment
#
# Create a Python virtual environment to isolate dependencies.

# %%
# !python -m venv .venv

# %% [markdown]
# ## 3. Install Jupyter and Dependencies
#
# Install Jupyter Notebook and any required libraries like NumPy or Pandas.

# %%
# !pip install jupyter numpy pandas matplotlib scikit-learn tensorflow opencv-python pillow

# %% [markdown]
# ## 4. Create Sample Notebook
#
# Create a basic Jupyter notebook file with initial cells.

# %%
import numpy as np
import pandas as pd
print("Sample notebook with basic imports created.")

# %% [markdown]
# ## 5. Configure .gitignore
#
# Set up a .gitignore file to exclude unnecessary files like virtual environments and cache.

# %%
# !echo ".venv/" >> .gitignore
# !echo "*.ipynb_checkpoints/" >> .gitignore
